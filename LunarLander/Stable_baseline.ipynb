# %%
import gymnasium as gym
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv, VecVideoRecorder
from stable_baselines3.common.evaluation import evaluate_policy
import numpy as np
import os

# %%
class TimeLimitRewardWrapper(gym.Wrapper):
    def __init__(self, env, max_seconds=10, fps=50):
        super().__init__(env)
        self.max_steps = max_seconds * fps  # 10 seconds × 50 FPS = 500 steps
        self.current_step = 0

    def reset(self, **kwargs):
        self.current_step = 0
        return self.env.reset(**kwargs)

    def step(self, action):
        observation, reward, terminated, truncated, info = self.env.step(action)
        self.current_step += 1

        if self.current_step >= self.max_steps:
            truncated = True
            reward -= 100  # Apply heavy penalty if timeout without landing

        return observation, reward, terminated, truncated, info

# %%
# ✅ Setup environment
env_id = "LunarLander-v3"

def make_env():
    env = gym.make(env_id, render_mode="rgb_array")
    env = TimeLimitRewardWrapper(env, max_seconds=10, fps=50)
    return env

# DummyVecEnv for SB3
env = DummyVecEnv([make_env])

# ✅ Folder for training videos
training_video_folder = "./training_videos/"
os.makedirs(training_video_folder, exist_ok=True)

# ✅ Wrap with video recorder
env = VecVideoRecorder(
    env,
    training_video_folder,
    record_video_trigger=lambda step: step < 5000,
    video_length=500,
    name_prefix="training"
)

# %%
# ✅ Model setup
model = DQN(
    policy="MlpPolicy",
    env=env,
    learning_rate=1e-3,
    buffer_size=1000000,
    learning_starts=1000,
    batch_size=64,
    gamma=0.99,
    train_freq=4,
    target_update_interval=500,
    verbose=1,
    tensorboard_log="./dqn_lunar_tensorboard/"
)

# ✅ Train the model
model.learn(total_timesteps=500000)

# ✅ Save the model
model.save("dqn_lunarlander_v3")

# ✅ Close training env
env.close()
# Out:
# Using cpu device
# Logging to ./dqn_lunar_tensorboard/DQN_2
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 321      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 403      |
# ----------------------------------
# Saving video to /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-0-to-step-500.mp4
# MoviePy - Building video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-0-to-step-500.mp4.
# MoviePy - Writing video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-0-to-step-500.mp4
# MoviePy - Done !
# MoviePy - video ready /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-0-to-step-500.mp4
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 285      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 780      |
# ----------------------------------
# Saving video to /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-501-to-step-1001.mp4
# MoviePy - Building video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-501-to-step-1001.mp4.
# MoviePy - Writing video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-501-to-step-1001.mp4
# MoviePy - Done !
# MoviePy - video ready /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-501-to-step-1001.mp4
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 272      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1187     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.959    |
# |    n_updates        | 46       |
# ----------------------------------
# Saving video to /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-1002-to-step-1502.mp4
# MoviePy - Building video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-1002-to-step-1502.mp4.
# MoviePy - Writing video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-1002-to-step-1502.mp4
# MoviePy - Done !
# MoviePy - video ready /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-1002-to-step-1502.mp4
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 253      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 1583     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.84     |
# |    n_updates        | 145      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 241      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 1996     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.521    |
# |    n_updates        | 248      |
# ----------------------------------
# Saving video to /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-1503-to-step-2003.mp4
# MoviePy - Building video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-1503-to-step-2003.mp4.
# MoviePy - Writing video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-1503-to-step-2003.mp4
# MoviePy - Done !
# MoviePy - video ready /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-1503-to-step-2003.mp4
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 235      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 2363     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.548    |
# |    n_updates        | 340      |
# ----------------------------------
# Saving video to /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-2004-to-step-2504.mp4
# MoviePy - Building video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-2004-to-step-2504.mp4.
# MoviePy - Writing video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-2004-to-step-2504.mp4
# MoviePy - Done !
# MoviePy - video ready /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-2004-to-step-2504.mp4
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 230      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 2761     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.357    |
# |    n_updates        | 440      |
# ----------------------------------
# Saving video to /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-2505-to-step-3005.mp4
# MoviePy - Building video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-2505-to-step-3005.mp4.
# MoviePy - Writing video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-2505-to-step-3005.mp4
# MoviePy - Done !
# MoviePy - video ready /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-2505-to-step-3005.mp4
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 222      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 3181     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.93     |
# |    n_updates        | 545      |
# ----------------------------------
# Saving video to /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-3006-to-step-3506.mp4
# MoviePy - Building video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-3006-to-step-3506.mp4.
# MoviePy - Writing video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-3006-to-step-3506.mp4
# MoviePy - Done !
# MoviePy - video ready /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-3006-to-step-3506.mp4
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 218      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 3562     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.511    |
# |    n_updates        | 640      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 217      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 3913     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.388    |
# |    n_updates        | 728      |
# ----------------------------------
# Saving video to /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-3507-to-step-4007.mp4
# MoviePy - Building video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-3507-to-step-4007.mp4.
# MoviePy - Writing video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-3507-to-step-4007.mp4
# MoviePy - Done !
# MoviePy - video ready /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-3507-to-step-4007.mp4
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 214      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 4326     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.9      |
# |    n_updates        | 831      |
# ----------------------------------
# Saving video to /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-4008-to-step-4508.mp4
# MoviePy - Building video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-4008-to-step-4508.mp4.
# MoviePy - Writing video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-4008-to-step-4508.mp4
# MoviePy - Done !
# MoviePy - video ready /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-4008-to-step-4508.mp4
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 212      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 4710     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.914    |
# |    n_updates        | 927      |
# ----------------------------------
# Saving video to /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-4509-to-step-5009.mp4
# MoviePy - Building video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-4509-to-step-5009.mp4.
# MoviePy - Writing video /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-4509-to-step-5009.mp4
# MoviePy - Done !
# MoviePy - video ready /home/amd/prajwal/RL_Playground/LunarLander/training_videos/training-step-4509-to-step-5009.mp4
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 213      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 5047     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.33     |
# |    n_updates        | 1011     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 224      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 5376     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.933    |
# |    n_updates        | 1093     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 237      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 5752     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.327    |
# |    n_updates        | 1187     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 249      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 6147     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.976    |
# |    n_updates        | 1286     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 263      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 6590     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.733    |
# |    n_updates        | 1397     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 273      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 6965     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.459    |
# |    n_updates        | 1491     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 284      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 7362     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.93     |
# |    n_updates        | 1590     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 294      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 7722     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.28     |
# |    n_updates        | 1680     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 303      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 8091     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.16     |
# |    n_updates        | 1772     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 313      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 8472     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.73     |
# |    n_updates        | 1867     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 321      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 8813     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.686    |
# |    n_updates        | 1953     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 331      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 9246     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.11     |
# |    n_updates        | 2061     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.815    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 342      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 9711     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.81     |
# |    n_updates        | 2177     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 350      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 10070    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.58     |
# |    n_updates        | 2267     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 359      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 10483    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.87     |
# |    n_updates        | 2370     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.793    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 368      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 10893    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.04     |
# |    n_updates        | 2473     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 376      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 11292    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.58     |
# |    n_updates        | 2572     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.778    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 383      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 11660    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.19     |
# |    n_updates        | 2664     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.769    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 392      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 12141    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.53     |
# |    n_updates        | 2785     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 399      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 12520    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.12     |
# |    n_updates        | 2879     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 408      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 13002    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.2      |
# |    n_updates        | 3000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.744    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 415      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 13469    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.05     |
# |    n_updates        | 3117     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.738    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 420      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 13812    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.591    |
# |    n_updates        | 3202     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.731    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 427      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 14179    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.7      |
# |    n_updates        | 3294     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.722    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 435      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 14632    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.29     |
# |    n_updates        | 3407     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 441      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 15028    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.794    |
# |    n_updates        | 3506     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.707    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 448      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 15434    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.35     |
# |    n_updates        | 3608     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.695    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 456      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 16030    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.35     |
# |    n_updates        | 3757     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.686    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 463      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 16509    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.84     |
# |    n_updates        | 3877     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.678    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 468      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 16926    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.49     |
# |    n_updates        | 3981     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.671    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 473      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 17292    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.42     |
# |    n_updates        | 4072     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.662    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 480      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 17813    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.645    |
# |    n_updates        | 4203     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.654    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 485      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 18204    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.7      |
# |    n_updates        | 4300     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.647    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 490      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 18593    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.421    |
# |    n_updates        | 4398     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.641    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 495      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 18905    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.438    |
# |    n_updates        | 4476     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.634    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 499      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 19281    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.716    |
# |    n_updates        | 4570     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.627    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 504      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 19643    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.465    |
# |    n_updates        | 4660     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.618    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 509      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 20080    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.17     |
# |    n_updates        | 4769     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.61     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 515      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 20535    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.69     |
# |    n_updates        | 4883     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.601    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 520      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 21002    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.48     |
# |    n_updates        | 5000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.586    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 525      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 21778    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.561    |
# |    n_updates        | 5194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.578    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 530      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 22236    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.427    |
# |    n_updates        | 5308     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.566    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 536      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 22830    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.23     |
# |    n_updates        | 5457     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.559    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 540      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 23202    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.11     |
# |    n_updates        | 5550     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.551    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 544      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 23620    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.21     |
# |    n_updates        | 5654     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.543    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 548      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 24034    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.45     |
# |    n_updates        | 5758     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.531    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 553      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 24675    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.797    |
# |    n_updates        | 5918     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.522    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 558      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 25157    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.23     |
# |    n_updates        | 6039     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.514    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 562      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 25597    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.859    |
# |    n_updates        | 6149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.506    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 566      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 25996    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.07     |
# |    n_updates        | 6248     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.492    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 570      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 26729    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.438    |
# |    n_updates        | 6432     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.482    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 574      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 27252    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.818    |
# |    n_updates        | 6562     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.46     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 576      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 28444    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.04     |
# |    n_updates        | 6860     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 581      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 29225    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.825    |
# |    n_updates        | 7056     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.434    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 585      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 29779    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.53     |
# |    n_updates        | 7194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.419    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 589      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 30592    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.64     |
# |    n_updates        | 7397     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.401    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 593      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 31525    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.856    |
# |    n_updates        | 7631     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.381    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 596      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 32585    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.01     |
# |    n_updates        | 7896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.371    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 599      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 33080    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.526    |
# |    n_updates        | 8019     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.355    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 602      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 33969    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.55     |
# |    n_updates        | 8242     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.326    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 603      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 35486    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.93     |
# |    n_updates        | 8621     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.288    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 604      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 37486    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.825    |
# |    n_updates        | 9121     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.255    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 606      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 39236    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.31     |
# |    n_updates        | 9558     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.217    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 605      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 41236    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.69     |
# |    n_updates        | 10058    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.179    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 606      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 43236    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.46     |
# |    n_updates        | 10558    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.143    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 606      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 45123    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.1      |
# |    n_updates        | 11030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.108    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 605      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 46960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.671    |
# |    n_updates        | 11489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0698   |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 604      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 48960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.44     |
# |    n_updates        | 11989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 605      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 50960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.93     |
# |    n_updates        | 12489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 604      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 52960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.87     |
# |    n_updates        | 12989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 606      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 54960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.975    |
# |    n_updates        | 13489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 607      |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 56960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.87     |
# |    n_updates        | 13989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 606      |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 58960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.639    |
# |    n_updates        | 14489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 605      |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 60960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.1      |
# |    n_updates        | 14989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 605      |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 62960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.12     |
# |    n_updates        | 15489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 607      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 64960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.33     |
# |    n_updates        | 15989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 607      |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 66960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.74     |
# |    n_updates        | 16489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 608      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 68960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.56     |
# |    n_updates        | 16989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 609      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 70960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.27     |
# |    n_updates        | 17489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 610      |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 72960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.33     |
# |    n_updates        | 17989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 609      |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 74960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.59     |
# |    n_updates        | 18489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 609      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 76960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.819    |
# |    n_updates        | 18989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 609      |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 78960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.22     |
# |    n_updates        | 19489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# ...
# |    n_updates        | 107562   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 605      |
# |    time_elapsed     | 715      |
# |    total_timesteps  | 433242   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.46     |
# |    n_updates        | 108060   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 605      |
# |    time_elapsed     | 718      |
# |    total_timesteps  | 435183   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.49     |
# |    n_updates        | 108545   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 605      |
# |    time_elapsed     | 721      |
# |    total_timesteps  | 437011   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.542    |
# |    n_updates        | 109002   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 605      |
# |    time_elapsed     | 724      |
# |    total_timesteps  | 439011   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.59     |
# |    n_updates        | 109502   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 605      |
# |    time_elapsed     | 727      |
# |    total_timesteps  | 440851   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.483    |
# |    n_updates        | 109962   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 605      |
# |    time_elapsed     | 730      |
# |    total_timesteps  | 442851   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.302    |
# |    n_updates        | 110462   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 605      |
# |    time_elapsed     | 734      |
# |    total_timesteps  | 444754   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.786    |
# |    n_updates        | 110938   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 605      |
# |    time_elapsed     | 737      |
# |    total_timesteps  | 446754   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.434    |
# |    n_updates        | 111438   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 605      |
# |    time_elapsed     | 741      |
# |    total_timesteps  | 448754   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.382    |
# |    n_updates        | 111938   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1148     |
# |    fps              | 605      |
# |    time_elapsed     | 744      |
# |    total_timesteps  | 450754   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.232    |
# |    n_updates        | 112438   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1152     |
# |    fps              | 605      |
# |    time_elapsed     | 748      |
# |    total_timesteps  | 452754   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.305    |
# |    n_updates        | 112938   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1156     |
# |    fps              | 604      |
# |    time_elapsed     | 751      |
# |    total_timesteps  | 454754   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.235    |
# |    n_updates        | 113438   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 604      |
# |    time_elapsed     | 755      |
# |    total_timesteps  | 456754   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.248    |
# |    n_updates        | 113938   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1164     |
# |    fps              | 604      |
# |    time_elapsed     | 758      |
# |    total_timesteps  | 458754   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.556    |
# |    n_updates        | 114438   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1168     |
# |    fps              | 604      |
# |    time_elapsed     | 762      |
# |    total_timesteps  | 460754   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.46     |
# |    n_updates        | 114938   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1172     |
# |    fps              | 604      |
# |    time_elapsed     | 765      |
# |    total_timesteps  | 462550   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.418    |
# |    n_updates        | 115387   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1176     |
# |    fps              | 604      |
# |    time_elapsed     | 767      |
# |    total_timesteps  | 464027   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.23     |
# |    n_updates        | 115756   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 604      |
# |    time_elapsed     | 770      |
# |    total_timesteps  | 465611   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.226    |
# |    n_updates        | 116152   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 604      |
# |    time_elapsed     | 773      |
# |    total_timesteps  | 467433   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.343    |
# |    n_updates        | 116608   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1188     |
# |    fps              | 604      |
# |    time_elapsed     | 776      |
# |    total_timesteps  | 469265   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.88     |
# |    n_updates        | 117066   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1192     |
# |    fps              | 604      |
# |    time_elapsed     | 779      |
# |    total_timesteps  | 471265   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.603    |
# |    n_updates        | 117566   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1196     |
# |    fps              | 604      |
# |    time_elapsed     | 782      |
# |    total_timesteps  | 472960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.62     |
# |    n_updates        | 117989   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 604      |
# |    time_elapsed     | 785      |
# |    total_timesteps  | 474960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.11     |
# |    n_updates        | 118489   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1204     |
# |    fps              | 604      |
# |    time_elapsed     | 789      |
# |    total_timesteps  | 476960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.364    |
# |    n_updates        | 118989   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1208     |
# |    fps              | 604      |
# |    time_elapsed     | 792      |
# |    total_timesteps  | 478960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.269    |
# |    n_updates        | 119489   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1212     |
# |    fps              | 604      |
# |    time_elapsed     | 795      |
# |    total_timesteps  | 480960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.387    |
# |    n_updates        | 119989   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1216     |
# |    fps              | 604      |
# |    time_elapsed     | 799      |
# |    total_timesteps  | 482960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.306    |
# |    n_updates        | 120489   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1220     |
# |    fps              | 604      |
# |    time_elapsed     | 802      |
# |    total_timesteps  | 484960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.298    |
# |    n_updates        | 120989   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1224     |
# |    fps              | 604      |
# |    time_elapsed     | 805      |
# |    total_timesteps  | 486960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.318    |
# |    n_updates        | 121489   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1228     |
# |    fps              | 604      |
# |    time_elapsed     | 808      |
# |    total_timesteps  | 488716   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.458    |
# |    n_updates        | 121928   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1232     |
# |    fps              | 604      |
# |    time_elapsed     | 811      |
# |    total_timesteps  | 490716   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.316    |
# |    n_updates        | 122428   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1236     |
# |    fps              | 604      |
# |    time_elapsed     | 815      |
# |    total_timesteps  | 492716   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.09     |
# |    n_updates        | 122928   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1240     |
# |    fps              | 604      |
# |    time_elapsed     | 818      |
# |    total_timesteps  | 494716   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.263    |
# |    n_updates        | 123428   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1244     |
# |    fps              | 604      |
# |    time_elapsed     | 821      |
# |    total_timesteps  | 496716   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.99     |
# |    n_updates        | 123928   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1248     |
# |    fps              | 604      |
# |    time_elapsed     | 824      |
# |    total_timesteps  | 498399   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.609    |
# |    n_updates        | 124349   |
# ----------------------------------

# %%
# ✅ Reload environment for evaluation (also with time wrapper)
eval_env = gym.make(env_id, render_mode="rgb_array")
eval_env = TimeLimitRewardWrapper(eval_env, max_seconds=10, fps=50)
eval_env = DummyVecEnv([lambda: eval_env])

# ✅ Reload model
model = DQN.load("dqn_lunarlander_v3", env=eval_env)

# ✅ Evaluate
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
print(f"✅ Mean Reward over 10 Evaluation Episodes: {mean_reward:.2f} ± {std_reward:.2f}")
# Out:
# /home/amd/prajwal/RL_Playground/.venv/lib/python3.11/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ✅ Mean Reward over 10 Evaluation Episodes: -23.81 ± 18.66

# %%
# ✅ New folder for final videos
final_video_folder = "./final_model_videos/"
os.makedirs(final_video_folder, exist_ok=True)

# ✅ Setup environment for final recording
record_env = gym.make(env_id, render_mode="rgb_array")
record_env = TimeLimitRewardWrapper(record_env, max_seconds=10, fps=50)
record_env = DummyVecEnv([lambda: record_env])

record_env = VecVideoRecorder(
    record_env,
    final_video_folder,
    record_video_trigger=lambda step: True,
    video_length=1000,
    name_prefix="final_model"
)

# ✅ Play 5 episodes
obs = record_env.reset()
episode = 0
while episode < 5:
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, infos = record_env.step(action)
    if dones[0]:
        obs = record_env.reset()
        episode += 1

record_env.close()
print("✅ Final 5 Episodes Recorded Successfully!")
# Out:
# MoviePy - Building video /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-500-to-step-1500.mp4.
# MoviePy - Writing video /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-500-to-step-1500.mp4
# MoviePy - Done !
# MoviePy - video ready /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-500-to-step-1500.mp4
# MoviePy - Building video /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-1000-to-step-2000.mp4.
# MoviePy - Writing video /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-1000-to-step-2000.mp4
# MoviePy - Done !
# MoviePy - video ready /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-1000-to-step-2000.mp4
# MoviePy - Building video /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-1500-to-step-2500.mp4.
# MoviePy - Writing video /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-1500-to-step-2500.mp4
# MoviePy - Done !
# MoviePy - video ready /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-1500-to-step-2500.mp4
# MoviePy - Building video /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-2000-to-step-3000.mp4.
# MoviePy - Writing video /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-2000-to-step-3000.mp4
# MoviePy - Done !
# MoviePy - video ready /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-2000-to-step-3000.mp4
# MoviePy - Building video /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-2500-to-step-3500.mp4.
# MoviePy - Writing video /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-2500-to-step-3500.mp4
# MoviePy - Done !
# MoviePy - video ready /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-2500-to-step-3500.mp4
# MoviePy - Building video /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-2500-to-step-3500.mp4.
# MoviePy - Writing video /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-2500-to-step-3500.mp4
# MoviePy - Done !
# MoviePy - video ready /home/amd/prajwal/RL_Playground/LunarLander/final_model_videos/final_model-step-2500-to-step-3500.mp4
# ✅ Final 5 Episodes Recorded Successfully!
